# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
LR = LinearRegression()
a = pd.read_csv('/content/car_data.csv')

# %%
a.head(20)
# Out:
#     city_mpg                        class  combination_mpg  cylinders  \
# 0         25                  midsize car               29        4.0
# 1         26                  midsize car               30        4.0
# 2         25  small sport utility vehicle               27        4.0
# 3         26  small sport utility vehicle               29        4.0
# 4         26  small sport utility vehicle               28        4.0
# 5         24  small sport utility vehicle               26        4.0
# 6         25  small sport utility vehicle               27        4.0
# 7         19               subcompact car               22        6.0
# 8         19               subcompact car               23        6.0
# 9         15               subcompact car               18        8.0
# 10        18               subcompact car               20        8.0
# 11        22  small sport utility vehicle               24        4.0
# ...

# %%
p = LinearRegression()

# %%
a.isnull().sum()
# Out:
# city_mpg           0
# class              0
# combination_mpg    0
# cylinders          0
# displacement       0
# drive              0
# fuel_type          0
# highway_mpg        0
# make               0
# model              0
# transmission       0
# year               0
# dtype: int64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 548 entries, 0 to 549
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   city_mpg         548 non-null    int64
#  1   class            548 non-null    object
#  2   combination_mpg  548 non-null    int64
#  3   cylinders        548 non-null    float64
#  4   displacement     548 non-null    float64
#  5   drive            548 non-null    object
#  6   fuel_type        548 non-null    object
#  7   highway_mpg      548 non-null    int64
#  8   make             548 non-null    object
#  9   model            548 non-null    object
#  10  transmission     548 non-null    object
#  11  year             548 non-null    int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 55.7+ KB

# %%
a.dropna(inplace=True)

# %%
a.isnull().sum()
# Out:
# city_mpg           0
# class              0
# combination_mpg    0
# cylinders          0
# displacement       0
# drive              0
# fuel_type          0
# highway_mpg        0
# make               0
# model              0
# transmission       0
# year               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le1 = LabelEncoder()

# %%
a['new_make'] = le.fit_transform(a['make'])
a['new_model'] = le1.fit_transform(a['model'])

# %%
x = a[['new_make','new_model','city_mpg','combination_mpg']]
y = a['highway_mpg']

# %%
p.fit(x,y)
# Out:
# LinearRegression()

# %%
print("the predicted fuel efficiency of the car in highways is ",p.predict([[2,1,24,26]]))
# Out:
# the predicted fuel efficiency of the car in highways is  [30.36853652]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
